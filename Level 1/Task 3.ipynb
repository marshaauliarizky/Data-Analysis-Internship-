# %% [markdown]
# ## Task 3: Basic Data Visualization

# %% [markdown]
# #### Bar Plot (Species Count)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("iris.csv")

# %%
plt.figure(figsize=(6,4))

sns.countplot(
    data=df,
    x="species"
)

plt.title("Number of Samples per Species")
plt.xlabel("Species")
plt.ylabel("Count")
plt.tight_layout()

plt.savefig("barplot_species.png")
plt.show()

# %% [markdown]
# #### Interpretation
#
# The bar plot shows the number of samples for each species.
#
# From the visualization:
#
# - Each species appears evenly distributed.
#
# - The dataset is balanced across categories.
#
# This is important because balanced data improves model reliability.

# %% [markdown]
# #### Line Chart

# %%
plt.figure(figsize=(6,4))

mean_petal = df.groupby("species")["petal_length"].mean()

mean_petal.plot(marker='o')

plt.title("Average Petal Length per Species")
plt.xlabel("Species")
plt.ylabel("Average Petal Length")
plt.grid(True)

plt.tight_layout()
plt.savefig("linechart_petal_length.png")
plt.show()

# %% [markdown]
# #### Interpretation
#
# The line chart shows:
#
# - Setosa has the smallest average petal length.
#
# - Versicolor is in the middle.
#
# - Virginica has the largest petal length.
#
# This confirms visible differences between species.

# %% [markdown]
# #### Scatter Plot

# %%
plt.figure(figsize=(6,4))

sns.scatterplot(
    data=df,
    x="sepal_length",
    y="sepal_width",
    hue="species"
)

plt.title("Sepal Length vs Sepal Width")
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.legend(title="Species")

plt.tight_layout()
plt.savefig("scatterplot_sepal.png")
plt.show()

# %% [markdown]
# #### Interpretation
#
# The scatter plot shows:
#
# - Setosa tends to cluster separately.
#
# - Versicolor and Virginica overlap slightly.
#
# - There is moderate relationship between sepal length and width.
#
# This visualization helps identify natural groupings in the dataset.

# %% [markdown]
# #### Final Conclusion
# In this task, I created bar plots, line charts, and scatter plots to visualize categorical distribution and numerical relationships. The visualizations highlight clear differences between species, especially in petal measurements. All plots were customized with proper labels, titles, legends, and exported as image files for reporting purposes.
